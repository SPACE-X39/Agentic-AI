# %%
print("all good")
# Out:
# all good

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

# pass API key explicitly (or set GOOGLE_API_KEY/GEMINI_API_KEY in env)
chat_llm = ChatGoogleGenerativeAI(model="gemini-3-flash-preview", api_key=os.getenv("API_KEY"))
print('Chat model instantiated')
# Out:
# Chat model instantiated

# %%
chat_llm.invoke("Hello, How are you?").content
# Out:
# [{'type': 'text',
#   'text': "Hello! I'm doing well, thank you for asking. How are you doing today? Is there anything I can help you with?",
#   'extras': {'signature': '...'}}]
